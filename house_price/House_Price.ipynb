# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data = pd.read_csv('housing.csv')

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
#removing null values
data.dropna(inplace =True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x= data.drop(['median_house_value'], axis=1)
y= data['median_house_value']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 2)

# %%
train_data=X_train.join(Y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2518     -122.13     39.74                20.0       1401.0           280.0
# 11511    -118.11     33.73                32.0       1258.0           333.0
# 8557     -118.40     33.93                35.0       2217.0           447.0
# 5778     -118.26     34.15                14.0       2981.0           894.0
# 1161     -121.54     39.51                33.0       3585.0           757.0
# ...          ...       ...                 ...          ...             ...
# 1106     -121.60     39.80                10.0       1742.0           307.0
# 19081    -122.48     38.31                29.0       2375.0           560.0
# 11915    -117.40     33.95                46.0       2189.0           423.0
# 6709     -118.15     34.14                52.0        403.0           117.0
# 2595     -123.74     40.66                25.0       2395.0           431.0
#
#        population  households  median_income ocean_proximity  \
# 2518        668.0       250.0         2.2569          INLAND
# 11511       645.0       334.0         5.0476      NEAR OCEAN
# 8557       1000.0       450.0         4.7319       <1H OCEAN
# 5778       1941.0       863.0         3.0000       <1H OCEAN
# 1161       1887.0       765.0         2.5020          INLAND
# ...           ...         ...            ...             ...
# 1106        721.0       312.0         2.4537          INLAND
# 19081      1124.0       502.0         2.3276       <1H OCEAN
# 11915       866.0       389.0         3.1384          INLAND
# 6709        361.0       105.0         1.6250       <1H OCEAN
# 2595        983.0       375.0         3.0469       <1H OCEAN
#
#        median_house_value
# 2518              94300.0
# 11511            500001.0
# 8557             376100.0
# 5778             178600.0
# 1161              62100.0
# ...                   ...
# 1106             117900.0
# 19081            166200.0
# 11915            111500.0
# 6709             187500.0
# 2595             136000.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(12,10))
plt.show()

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924641           -0.115105     0.041673
# latitude            -0.924641  1.000000            0.016029    -0.032829
# housing_median_age  -0.115105  0.016029            1.000000    -0.359047
# total_rooms          0.041673 -0.032829           -0.359047     1.000000
# total_bedrooms       0.064607 -0.062098           -0.320782     0.929783
# population           0.095802 -0.105209           -0.294075     0.853380
# households           0.050579 -0.066641           -0.301494     0.918067
# median_income       -0.013082 -0.081778           -0.113630     0.196223
# median_house_value  -0.042526 -0.146616            0.107148     0.134643
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.064607    0.095802    0.050579      -0.013082
# latitude                 -0.062098   -0.105209   -0.066641      -0.081778
# housing_median_age       -0.320782   -0.294075   -0.301494      -0.113630
# total_rooms               0.929783    0.853380    0.918067       0.196223
# total_bedrooms            1.000000    0.874996    0.978691      -0.010787
# population                0.874996    1.000000    0.905963      -0.000229
# households                0.978691    0.905963    1.000000       0.010330
# median_income            -0.010787   -0.000229    0.010330       1.000000
# median_house_value        0.049845   -0.025813    0.065421       0.691863
#
#                     median_house_value
# longitude                    -0.042526
# latitude                     -0.146616
# housing_median_age            0.107148
# total_rooms                   0.134643
# total_bedrooms                0.049845
# population                   -0.025813
# households                    0.065421
# median_income                 0.691863
# median_house_value            1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train_data.corr(), cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':8}, cmap='Blues')
plt.show()

# %% [markdown]
# ## Data preprocessing

# %%
train_data['total_rooms']= np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']= np.log(train_data['total_bedrooms']+1)
train_data['population']= np.log(train_data['population']+1)
train_data['households']= np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(12,10))
plt.show()

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7254
# INLAND        5185
# NEAR OCEAN    2090
# NEAR BAY      1815
# ISLAND           2
# Name: ocean_proximity, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2518           0       1       0         0           0
# 11511          0       0       0         0           1
# 8557           1       0       0         0           0
# 5778           1       0       0         0           0
# 1161           0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 1106           0       1       0         0           0
# 19081          1       0       0         0           0
# 11915          0       1       0         0           0
# 6709           1       0       0         0           0
# 2595           1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data= train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2518     -122.13     39.74                20.0     7.245655        5.638355
# 11511    -118.11     33.73                32.0     7.138073        5.811141
# 8557     -118.40     33.93                35.0     7.704361        6.104793
# 5778     -118.26     34.15                14.0     8.000349        6.796824
# 1161     -121.54     39.51                33.0     8.184793        6.630683
# ...          ...       ...                 ...          ...             ...
# 1106     -121.60     39.80                10.0     7.463363        5.730100
# 19081    -122.48     38.31                29.0     7.773174        6.329721
# 11915    -117.40     33.95                46.0     7.691657        6.049733
# 6709     -118.15     34.14                52.0     6.001415        4.770685
# 2595     -123.74     40.66                25.0     7.781556        6.068426
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 2518     6.505784    5.525453         2.2569             94300.0          0
# 11511    6.470800    5.814131         5.0476            500001.0          0
# 8557     6.908755    6.111467         4.7319            376100.0          1
# 5778     7.571474    6.761573         3.0000            178600.0          1
# 1161     7.543273    6.641182         2.5020             62100.0          0
# ...           ...         ...            ...                 ...        ...
# 1106     6.582025    5.746203         2.4537            117900.0          0
# 19081    7.025538    6.220590         2.3276            166200.0          1
# 11915    6.765039    5.966147         3.1384            111500.0          0
# 6709     5.891644    4.663439         1.6250            187500.0          1
# 2595     6.891626    5.929589         3.0469            136000.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2518        1       0         0           0
# 11511       0       0         0           1
# 8557        0       0         0           0
# 5778        0       0         0           0
# 1161        1       0         0           0
# ...       ...     ...       ...         ...
# 1106        1       0         0           0
# 19081       0       0         0           0
# 11915       1       0         0           0
# 6709        0       0         0           0
# 2595        0       0         0           0
#
# [16346 rows x 14 columns]

# %%
#Checking new corelations
plt.figure(figsize=(10,10))
sns.heatmap(train_data.corr(), cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':12}, cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=train_data, x="latitude", y="longitude", hue="median_house_value", palette="coolwarm")
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/ train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms']/ train_data['households']

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train_data.corr(), cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':12}, cmap='Blues')
plt.show()

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
x_train_s =scaler.fit_transform(x_train)


lr =LinearRegression()
lr.fit(x_train_s,y_train)
# Out:
# LinearRegression()

# %%
test_data=X_test.join(Y_test)

test_data['total_rooms']= np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']= np.log(test_data['total_bedrooms']+1)
test_data['population']= np.log(test_data['population']+1)
test_data['households']= np.log(test_data['households']+1)

test_data= test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms']/ test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms']/ test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 356      -122.16     37.76                36.0     7.930925        6.354370
# 2192     -119.95     36.80                30.0     7.118016        5.370638
# 9161     -118.49     34.42                23.0     8.334952        6.629363
# 168      -122.24     37.79                27.0     7.398174        6.200509
# 13155    -121.45     36.86                11.0     7.386471        5.817111
# ...          ...       ...                 ...          ...             ...
# 6376     -118.03     34.15                43.0     7.435438        5.648974
# 13919    -115.85     34.20                34.0     8.260751        7.137278
# 4323     -118.35     34.09                42.0     7.701200        6.467699
# 3324     -122.89     38.93                20.0     7.102499        5.513429
# 15779    -122.41     37.78                52.0     5.541264        4.290459
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 356      7.271704    6.253829         2.4598            155500.0          0
# 2192     6.431331    5.298317         3.4297            112500.0          0
# 9161     7.641564    6.612041         4.4107            213400.0          1
# 168      7.066467    6.063785         2.3173            125000.0          0
# 13155    7.388946    5.837730         3.1375            146200.0          0
# ...           ...         ...            ...                 ...        ...
# 6376     6.514713    5.590987         4.1797            486800.0          0
# 13919    6.792344    6.049733         1.3571             41000.0          0
# 4323     7.113956    6.406880         2.5982            315800.0          1
# 3324     6.224558    5.411646         2.7188            105700.0          1
# 15779    5.036953    3.401197         3.8625            350000.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 356         0       0         1           0       0.801214         1.268171
# 2192        1       0         0           0       0.754513         1.343448
# 9161        0       0         0           0       0.795369         1.260572
# 168         0       0         1           0       0.838113         1.220059
# 13155       1       0         0           0       0.787536         1.265298
# ...       ...     ...       ...         ...            ...              ...
# 6376        1       0         0           0       0.759737         1.329897
# 13919       1       0         0           0       0.863999         1.365474
# 4323        0       0         0           0       0.839830         1.202020
# 3324        0       0         0           0       0.776266         1.312447
# 15779       0       0         1           0       0.774275         1.629210
#
# [4087 rows x 16 columns]

# %%
X_test, Y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']
X_test_s =scaler.fit_transform(X_test)
lr.score(X_test_s,Y_test)
# Out:
# 0.6569987218609015

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor()
rf.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test_s,Y_test)
# Out:
# 0.7800673377178149

# %%
from sklearn.model_selection import GridSearchCV
param_grid={
    "n_estimators":[30, 50, 100],
    "max_features":[2, 4, 6, 8]
}
grid_search = GridSearchCV(rf, param_grid, cv=5,
                          scoring="neg_mean_squared_error",
                          return_train_score= True)
grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [30, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(X_test_s,Y_test)
# Out:
# 0.7908062987025649

# %%
import xgboost as xgb
from xgboost import XGBRegressor

# %%
model = XGBRegressor()
model.fit(x_train_s, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
training_data_prediction = model.predict(x_train_s)
print(training_data_prediction)
# Out:
# [ 79058.14 415479.53 393033.6  ... 144731.92 189778.94 142347.6 ]

# %%
from sklearn import metrics
# R squared error
score_1 = metrics.r2_score(y_train, training_data_prediction)

# Mean Absolute Error
score_2 = metrics.mean_absolute_error(y_train, training_data_prediction)

print("R squared error : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared error :  0.9422582940795313
# Mean Absolute Error :  19832.017231255926

# %%
plt.scatter(y_train, training_data_prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()

# %%
test_data_prediction = model.predict(X_test_s)

# %%
score_1 = metrics.r2_score(Y_test, test_data_prediction)

# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_test, test_data_prediction)

print("R squared error : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared error :  0.8065474747479275
# Mean Absolute Error :  33641.97828910647
